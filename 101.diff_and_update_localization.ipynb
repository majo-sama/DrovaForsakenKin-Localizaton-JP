# %%
from pathlib import Path
from helpers import read_data_to_dict
from helpers import list_entries_recusive

previous_ver = "1.0.4"
new_ver = "1.0.4.2"

previous_ver_en = Path("data") / previous_ver / "Localization" / "en"
previous_ver_ja = Path("data") / previous_ver / "Localization" / "ja"
new_en_dir = Path("data") / new_ver / "Localization" / "en"


def read_localizatoin_dir_to_dict(localization_dir_path: Path) -> tuple[dict, list]:
    """Read localization directory to dictionary

    Args:
        localization_dir_path (Path): Path to localization directory

    Returns:
        tuple[dict, list]: Tuple of dictionary and list of exceptions

        Dictionary like {"path/to/file": {"game text key": "game text"}, ...}
    """
    entries = list_entries_recusive(localization_dir_path)
    result = {}
    exceptions = []

    for entry in entries:
        if entry.is_dir() or not entry.name.endswith(".loc"):
            print(f"Skipping {entry}")
            continue

        key = entry.relative_to(localization_dir_path).as_posix()
        value = entry.read_text()

        try:
            value_dict = read_data_to_dict(value)
            result[key] = value_dict
        except Exception:
            exceptions.append(key)

    return result, exceptions


previous_ja_dict, previous_ja_exceptions = read_localizatoin_dir_to_dict(previous_ver_ja)
previous_en_dict, previous_en_exceptions = read_localizatoin_dir_to_dict(previous_ver_en)
new_en_dict, new_en_exceptions = read_localizatoin_dir_to_dict(new_en_dir)
new_ja_dict = previous_ja_dict.copy()
# Out:
# Skipping data/1.0.4/Localization/ja/Journal
# Skipping data/1.0.4/Localization/ja/Dialogues
# Skipping data/1.0.4/Localization/ja/Letters
# Skipping data/1.0.4/Localization/ja/Dialog
# Skipping data/1.0.4/Localization/ja/Dialog/Footprint
# Skipping data/1.0.4/Localization/ja/Dialog/Perceptible
# Skipping data/1.0.4/Localization/ja/Dialog/Objects
# Skipping data/1.0.4/Localization/ja/Dialog/Corpses
# Skipping data/1.0.4/Localization/ja/Dialogue
# Skipping data/1.0.4/Localization/ja/NPC_Names
# Skipping data/1.0.4/Localization/ja/GUI
# Skipping data/1.0.4/Localization/ja/HUD
# Skipping data/1.0.4/Localization/en/Journal
# Skipping data/1.0.4/Localization/en/Dialogues
# Skipping data/1.0.4/Localization/en/Letters
# Skipping data/1.0.4/Localization/en/Dialog
# Skipping data/1.0.4/Localization/en/Dialog/Footprint
# Skipping data/1.0.4/Localization/en/Dialog/Perceptible
# Skipping data/1.0.4/Localization/en/Dialog/Objects
# Skipping data/1.0.4/Localization/en/Dialog/Corpses
# Skipping data/1.0.4/Localization/en/Dialogue
# Skipping data/1.0.4/Localization/en/NPC_Names
# Skipping data/1.0.4/Localization/en/GUI
# Skipping data/1.0.4/Localization/en/HUD
# Skipping data/1.0.4.2/Localization/en/Journal
# Skipping data/1.0.4.2/Localization/en/Dialogues
# Skipping data/1.0.4.2/Localization/en/Letters
# Skipping data/1.0.4.2/Localization/en/Dialog
# Skipping data/1.0.4.2/Localization/en/Dialog/Footprint
# Skipping data/1.0.4.2/Localization/en/Dialog/Perceptible
# Skipping data/1.0.4.2/Localization/en/Dialog/Objects
# Skipping data/1.0.4.2/Localization/en/Dialog/Corpses
# Skipping data/1.0.4.2/Localization/en/Dialogue
# Skipping data/1.0.4.2/Localization/en/NPC_Names
# Skipping data/1.0.4.2/Localization/en/GUI
# Skipping data/1.0.4.2/Localization/en/HUD

# %%
game_strings = ""
for k,v in previous_ja_dict.items():
    for kk, vv in v.items():
        game_strings += vv

len(game_strings)
# Out:
# 625527

# %%
previous_en_exceptions, new_en_exceptions
# Out:
# (['GUI/UserReport_en.loc'], ['GUI/UserReport_en.loc'])

# %%
def diff_dict_key_values(old: dict, new: dict) -> dict:
    difference = {
        "key_added": [],
        "key_removed": [],
        "value_updated": [],
    }
    for key, value in new.items():
        if key not in old:
            difference["key_added"].append(key)
        else:
            predict_value = old[key]
            if value != predict_value:
                difference["value_updated"].append(key)

    for key in old.keys():
        if key not in new:
            difference["key_removed"].append(key)

    return difference


# test
predict = {
    "a": "fooooo",
    "b": "removed!",
    "d": "removed!!",
}
actual = {
    "a": "foo, change!",
    "c": "new!",
}
res = diff_dict_key_values(predict, actual)
print(res)




def has_diff(old: dict, new: dict) -> bool:
    return diff_dict_key_values(old, new) != {"key_added": [], "key_removed": [], "value_updated": []}


# test
print(has_diff(predict, actual))
print(has_diff(predict, predict))
# Out:
# {'key_added': ['c'], 'key_removed': ['b', 'd'], 'value_updated': ['a']}
# True
# False

# %%
import difflib

def print_diff_hl(ground_truth, target):
    """
    Print diff result with colorful highlight
    """
    color_dic = {
        'red': '\033[31m',
        'green': '\033[32m',
        'end': '\033[0m'
    }

    d = difflib.Differ()
    diffs = list(d.compare(ground_truth, target))

    ground_truth_result = ''
    target_result = ''

    for diff in diffs:
        status = diff[0]
        character = diff[2]

        if status == '-':
            # ground truth の削除箇所を赤で表示
            ground_truth_result += color_dic['red'] + character + color_dic['end']
            target_result += ' '  # 削除部分はtargetに表示しない
        elif status == '+':
            # target の追加箇所を緑で表示
            ground_truth_result += ' '  # 追加部分はground truthに表示しない
            target_result += color_dic['green'] + character + color_dic['end']
        else:
            # 共通部分をそのまま表示
            ground_truth_result += character
            target_result += character

    print(f"ground truth : {ground_truth_result}")
    print(f"target       : {target_result}")

# テスト
ground_truth = "abcde"
target = "a ydef"
print_diff_hl(ground_truth, target)
# Out:
# ground truth : abc  de
# target       : a   ydef

# %%
# Search Differences
new_files = []
differences = {}


for new_file_key, new_file_content in new_en_dict.items():
    if new_file_key not in previous_en_dict.keys():
        print(f"New file found: {new_file_key}")
        new_files.append(new_file_key)
    else:
        previous_file_content = previous_en_dict[new_file_key]

        diff = diff_dict_key_values(previous_file_content, new_file_content)
        if diff == {"key_added": [], "key_removed": [], "value_updated": []}:
            # print(f"No diff found in {new_file}")
            continue
        else:
            print(f"Diff found in {new_file_key}")
            differences[new_file_key] = diff


# print results
print()
print("### New files\n", new_files)
print()
print("### Differences\n")
for new_file_key, diff in differences.items():
    print(f"{new_file_key}")

    if diff["key_added"]:
        print("Added keys\n", diff["key_added"], "\n")
    if diff["key_removed"]:
        print("Removed keys\n", diff["key_removed"], "\n")
    if diff["value_updated"]:
        print("Updated values\n")
        for key in diff["value_updated"]:
            print(f"--- Key: {key} ---")
            print_diff_hl(previous_en_dict[new_file_key][key], new_en_dict[new_file_key][key])
    print()
# Out:
# Diff found in Letters/Table_Brutus_en.loc
# Diff found in Dialog/NPC_Roarke_en.loc
#
# ### New files
#  []
#
# ### Differences
#
# Letters/Table_Brutus_en.loc
# Updated values
#
# --- Key: Letter_1 ---
# ground truth : Attempt number seven was... succes ful?<br>Drawing on the primal forces of the crystal, I was able to withstand the intense heat inside the vessel.<br><br>I found myself in a surreal world and met the spirits of nature.<br>I became nauseated. This may sound strange, but it was as though I could feel their mistrust in my veins.<br><br>How can I prove to them that I deserve their trust...?<br>Page 4
# target       : Attempt number seven was... successful?<br>Drawing on the primal forces of the crystal, I was able to withstand the intense heat inside the vessel.<br><br>I found myself in a surreal world and met the spirits of nature.<br>I became nauseated. This may sound strange, but it was as though I could feel their mistrust in my veins.<br><br>How can I prove to them that I deserve their trust...?<br>Page 4
#
# Dialog/NPC_Roarke_en.loc
# Updated values
#
# --- Key: Plh_234 ---
# ground truth : Cay has this incredible sense for finding the best mushrooms. When you feed him,, he usually darts off right away to get more. Could you take him and find some?
# target       : Cay has this incredible sense for finding the best mushrooms. When you feed him,  he usually darts off right away to get more. Could you take him and find some?

# %%
from typing import Optional
from llm_utils import get_llm_response

def get_noun_dictionary_prompt():
    """
    Get noun dictionary
    """
    dictionary = {
        "Georgefarm": "ジョージファーム",
        "apple grove": "リンゴ園",
        "Nemeton": "ネメトン",
        "Morbid Moor": "病み沼",
        "Red Moor": "レッドムーア",
        "Bygones": "古き者",
        "Mighty Boar": "マイティボア",
        "Hewers": "鉱夫",
        "Remnant's Camp": "はぐれ者のキャンプ",
        "Remnant": "はぐれ者",
        "Molvina": "モルヴィナ",
        "Pit": "ピット",
        "Heath": "荒れ地",
        "Rustmoss": "ラストモス",
        "Rustroot": "ラストルート",
        "Georg Farm": "ゲオルグ農場",
        "Headless Ripper Inn": "首なしリッパー宿屋",
        "the Marked Ones": "印の一団",
        "Proximus": "プロキシマス",
        "Blades of Jero ": "ジェロの刃",
        "Apple grove" : "リンゴ園",
    }

    prompt = f"""
翻訳時には、以下の固有名詞については、変換先に従って翻訳を行ってください。
{"\n".join([f"{key} => {value}" for key, value in dictionary.items()])}
"""
    return prompt

print(get_noun_dictionary_prompt())
# Out:
# 翻訳時には、以下の固有名詞については、変換先に従って翻訳を行ってください。
# Georgefarm => ジョージファーム
# apple grove => リンゴ園
# Nemeton => ネメトン
# Morbid Moor => 病み沼
# Red Moor => レッドムーア
# Bygones => 古き者
# Mighty Boar => マイティボア
# Hewers => 鉱夫
# Remnant's Camp => はぐれ者のキャンプ
# Remnant => はぐれ者
# Molvina => モルヴィナ
# Pit => ピット
# Heath => 荒れ地
# Rustmoss => ラストモス
# Rustroot => ラストルート
# Georg Farm => ゲオルグ農場
# Headless Ripper Inn => 首なしリッパー宿屋
# the Marked Ones => 印の一団
# Proximus => プロキシマス
# Blades of Jero  => ジェロの刃
# Apple grove => リンゴ園

# %%
def update_translation(source_sentence:str, translated_source_sentence: str, updated_source_sentence: str, context: Optional[str] = None) -> str:
    """
    Update translation with context and previsous translation
    """
    system_prompt = """You are a world class English-Japanese translator."""
    user_prompt = f"""これは古風なRPGにおけるテキストです。元文が更新されたため、翻訳文を更新したいです。
    「更新前の元文」と「更新前の翻訳文」を参考にして、その翻訳の語感・雰囲気などを維持したまま、内容を更新してください。
    また、翻訳文の品質を向上させるため、翻訳文の修正も行っていただいて構いません。
    口調はですます調は使わず、タメ口でお願いします。
    No Copy & Paste, No 1:1 Translation, No Literal Translation, No Transliteration.
    Don't forget to keep the tone and atmosphere of the translation consistent with the original text.
    Only output the translation text. Don't output explanation or the source text, etc.
    あなたの翻訳力とセンスを信じています。

    { "# Context / Background" if context else ""}
    { context if context else ""}

    # 更新前の元文
    {source_sentence}

    # 更新前の翻訳文:
    {translated_source_sentence}

    # 更新後の元文
    {updated_source_sentence}
    """
    updated_translation = get_llm_response(
        "gpt-4o-mini",
        messages=[
            { "role": "system", "content": system_prompt },
            { "role": "user", "content": user_prompt },
        ],
        params_={
            "temperature": 0,
        }

    )
    print("Original translation:", translated_source_sentence)
    print("Updated translation :", updated_translation)
    return updated_translation

# test
update_translation(
    "Rura wants me to take Muc to her. He's supposed to help with the work. Well, he's got to be somewhere.",
    "ルーラは私にムクを彼女のところに連れて行ってほしいと言っています。彼は仕事を手伝うことになっています。さて、彼はどこかにいるはずです。",
    "Rura wants me to take Muc to her. He's supposed to help with the work. Rura said that he actually wanted to go to Georgefarm. But it's also possible that he's already finished there and is perhaps lazing around in the apple grove east of Nemeton. I should have a look around.",
    context=get_noun_dictionary_prompt()
)
# Out:
# Original translation: ルーラは私にムクを彼女のところに連れて行ってほしいと言っています。彼は仕事を手伝うことになっています。さて、彼はどこかにいるはずです。
# Updated translation : ルーラはムクを彼女のところに連れて行ってほしいって言ってる。彼は仕事を手伝うことになってるんだ。ルーラによると、実はジョージファームに行きたがってたみたい。でも、もうそこでの仕事を終えて、ネメトンの東にあるリンゴ園でのんびりしてる可能性もある。ちょっと周りを見てみるべきだな。
# 'ルーラはムクを彼女のところに連れて行ってほしいって言ってる。彼は仕事を手伝うことになってるんだ。ルーラによると、実はジョージファームに行きたがってたみたい。でも、もうそこでの仕事を終えて、ネメトンの東にあるリンゴ園でのんびりしてる可能性もある。ちょっと周りを見てみるべきだな。'

# %%
def translate(source_sentence:str, context: Optional[str] = None, writing_style: str="") -> str:
    """
    Update translation with context and previsous translation
    """
    system_prompt = """You are a world class English-Japanese translator."""
    user_prompt = f"""これは古風なRPGにおけるテキストです。元文を日本語に翻訳してください。
    {writing_style}
    注意事項や背景情報は以下に記載しています。参考にして翻訳してください。
    No Copy & Paste, No 1:1 Translation, No Literal Translation, No Transliteration.
    Don't forget to keep the tone and atmosphere of the translation consistent with the original text.
    Only output the translation text. Don't output explanation or the source text, etc.
    あなたの翻訳力とセンスを信じています。

    { "# Context / Background" if context else ""}
    { context if context else ""}

    # 元文
    {source_sentence}
    """
    updated_translation = get_llm_response(
        "gpt-4o-mini",
        messages=[
            { "role": "system", "content": system_prompt },
            { "role": "user", "content": user_prompt },
        ],
        params_={
            "temperature": 0,
        }

    )
    print("Updated translation :", updated_translation)
    return updated_translation

translate(
    "Rura wants me to take Muc to her. He's supposed to help with the work. Rura said that he actually wanted to go to Georgefarm. But it's also possible that he's already finished there and is perhaps lazing around in the apple grove east of Nemeton. I should have a look around.",
    writing_style="口調はですます調は使わず、タメ口でお願いします。",
    context=get_noun_dictionary_prompt()
)
# Out:
# Updated translation : ルーラがムックを連れて行ってほしいって。彼は仕事を手伝うことになってるんだ。ルーラは、実は彼がジョージファームに行きたがってたって言ってたけど、もうそこでの仕事は終わってて、ネメトンの東にあるリンゴ園でのんびりしてる可能性もあるな。ちょっと周りを見てみるか。
# 'ルーラがムックを連れて行ってほしいって。彼は仕事を手伝うことになってるんだ。ルーラは、実は彼がジョージファームに行きたがってたって言ってたけど、もうそこでの仕事は終わってて、ネメトンの東にあるリンゴ園でのんびりしてる可能性もあるな。ちょっと周りを見てみるか。'

# %%
from helpers import write_dict_to_data
from helpers_llm import sniff_persona

print("# Show added translation keys")
for file, diff_dict in differences.items():

    npc_persona = None

    if diff_dict["key_added"]:
        for key in diff_dict["key_added"]:
            print(f"{key}")

            # TODO: create writing style class and use it from translation service
            writing_style = ""
            if "Journal" in str(file):
                writing_style = "口調はですます調でお願いします。"
            elif "NPC_" in str(file) and "Dialog" in str(file):
                if not npc_persona:
                    npc_name = Path(file).stem.split("_")[1]
                    print(f"NPC name: {npc_name}")
                    npc_persona = sniff_persona(
                        name = npc_name,
                        sentences=list(new_en_dict[file].values())
                    )
                    if npc_persona:
                        writing_style += f"""翻訳する文章はNPCのセリフです。次のNPCのペルソナに沿って翻訳文の雰囲気を決めてください: \n{npc_persona}"""
                else:
                    writing_style = npc_persona

            ja_file_key = file.replace("_en.", "_ja.")

            updated_traslation = translate(
                new_en_dict[file][key],
                context=get_noun_dictionary_prompt(),
                writing_style=writing_style
            )

            new_ja_dict[ja_file_key][key] = updated_traslation
            ja_file_path_obj = Path("data") / new_ver / "Localization" / "ja" / ja_file_key
            ja_file_path_obj.write_text(
                write_dict_to_data(new_ja_dict[ja_file_key])
            )

print("Done")
# Out:
# # Key Added
# Entry_03_Cancel
# Updated translation : 私はロボを叩きのめしましたので、彼はもう私と関わりたくないようです。
# Plh_70
# NPC name: Lobo
# Updated translation : いじめっ子とは関わりたくないね。
# Plh_183
# NPC name: Rura
# Updated translation : あのクソったれのムクがまたリンゴ園でゴロゴロしていないことを願うがな… *自分に言い聞かせるように*
# Plh_231
# NPC name: Bady
# Updated translation : 斧を手に入れるまでは戦えぬ。今はただ、訓練に励ませてくれ。
# Plh_232
# Updated translation : 食事を摂るまでは戦うことはできない。それまでは、訓練をさせてくれ。
# Plh_358
# NPC name: Agilo
# Updated translation : ゲロもはぐれ者のキャンプにいる。そこで彼に会ったんだ。
# Plh_170
# Updated translation : 傷んだ石の周りでは、沼がリンゴ園を再生しようとしているようだ。
# ChangeGameModeWarning
# Updated translation : アイアンモードを終了してもよろしいですか？もしそうする場合、ゲームの進行中にこのモードを再度有効にすることはできません。

# %%
from helpers import write_dict_to_data

assert 1==2, "comment out this line to regenerate translation"

print("# Value Updated")
for file, diff_dict in differences.items():
    if diff_dict["value_updated"]:
        print("------")
        print(f"{file.replace("_en.", "_ja.")}")
        for key in diff_dict["value_updated"]:
            print(f"{key}")
            print_diff_hl(previous_en_dict[file][key], new_en_dict[file][key])

            ja_file_key = file.replace("_en.", "_ja.")
            updated_traslation = update_translation(
                previous_en_dict[file][key],
                previous_ja_dict[ja_file_key][key],
                new_en_dict[file][key],
                context=get_noun_dictionary_prompt()
            )
            new_ja_dict[ja_file_key][key] = updated_traslation

            ja_file_path_obj = Path("data") / new_ver / "Localization" / "ja" / ja_file_key
            ja_file_path_obj.write_text(
                write_dict_to_data(new_ja_dict[ja_file_key])
            )

        print()

print("Done")
# Out:
# # Value Updated
# ------
# Journal/WayIntoTheCraftsHouse_ja.loc
# Entry_01
# ground truth : Rura wants me to take Muc to her. He's supposed to help with the work.     Well,       h    e                                            's g   ot t o    b e         s                                                o                                 me   where.
# target       : Rura wants me to take Muc to her. He's supposed to help with the work. Rura      said that he actually wanted to go to Georgefarm. But it's  also   po ssible that he's already finished there and is perhaps lazing around in the apple grove east of Nemeton     . I should have a look around.
# Original translation: ルーラはムクを彼女のところに連れて行ってほしいって言ってる。彼は仕事を手伝うことになってるんだ。ルーラによると、実はジョージファームに行きたがってたみたい。でも、もうそこでの仕事を終えて、ネメトンの東にあるリンゴ園でのんびりしてる可能性もあるな。ちょっと周りを探してみるべきだ。
# Updated translation : ルーラはムクを彼女のところに連れて行ってほしいって言ってる。彼は仕事を手伝うことになってるんだ。ルーラによると、実はジョージファームに行きたがってたみたい。でも、もうそこでの仕事を終えて、ネメトンの東にあるリンゴ園でのんびりしてるかもしれない。ちょっと周りを探してみるべきだな。
#
# ------
# Journal/BanditsOnTheBridge_ja.loc
# Entry_01
# ground truth : Delani put a request up on the bulletin board. She urgently needs help near the bridge. I'm supposed to report to her.
# target       : Delani put a request up on the bulletin board. She urgently needs help near the bridge. I'm supposed to report to her. I find them at Georgefarm.
# Original translation: デラニが掲示板にリクエストを出した。彼女は橋の近くで緊急の助けが必要なんだ。俺は彼女に報告することになってる。ジョージファームで彼女を見つけるつもりだ。
# Updated translation : デラニが掲示板にリクエストを出した。彼女は橋の近くで緊急の助けが必要なんだ。俺は彼女に報告することになってる。ジョージファームで彼女を見つけるつもりだ。
# Entry_03
# ground truth : The bandits are history. I should tell Delani about  th at           .
# target       : The bandits are history. I should tell Delani about it  at Georgefarm.
# Original translation: 盗賊たちはもう過去の話だ。ジョージファームでデラニにそのことを伝えなきゃ。
# Updated translation : 盗賊たちはもう過去の話だ。ジョージファームでデラニにそのことを伝えなきゃ。
# Entry_03B
# ground truth : When I told Delani that the bandits will no longer be a problem, that took a huge load off her mind. I'm supposed to receive my reward from Angus           .
# target       : When I told Delani that the bandits will no longer be a problem, that took a huge load off her mind. I'm supposed to receive my reward from Angus in Nemeton.
# Original translation: デラニに山賊がもう問題じゃなくなったって伝えたら、彼女はすごくホッとしたみたいだ。俺はネメトンでアンガスから報酬を受け取ることになってる。
# Updated translation : デラニに山賊がもう問題じゃなくなったって伝えたら、彼女はすごくホッとしたみたいだ。俺はネメトンでアンガスから報酬を受け取ることになってる。
#
# ------
# Journal/StalkerFlussbett_ja.loc
# Entry_02
# ground truth : I'm allowed into the P it         .
# target       : I'm allowed into the  si lver mine.
# Original translation: 私は銀鉱に入ることを許されてる。
# Updated translation : 私は銀鉱に入ることを許されてる。
#
# ------
# Journal/Rats_ja.loc
# Entry_03_B
# ground truth : The rats in the hidden cave are dead. Once I've taken care of the one   s still in the basement, I should report to Bernold.
# target       : The rats in the hidden cave are dead. Once I've taken care of the    rats still in the basement, I should report to Bernold.
# Original translation: 隠れた洞窟のネズミは死んでる。地下室にまだいるネズミを片付けたら、ベルノルドに報告しなきゃ。
# Updated translation : 隠れた洞窟のネズミは死んでる。地下室にまだいるネズミを片付けたら、ベルノルドに報告しなきゃ。
#
# ------
# Talents_ja.loc
# talent_tearclaws
# ground truth : G ut     Animal
# target       :  Pu ll Cl    a ws
# Original translation: 爪を引き抜け
# Updated translation : 爪を引き抜け
#
# ------
# Letters/Mikesch_ja.loc
# Text
# ground truth :       Palina, y                   ou      still owe    me a favor, and now I'm collecting on it.<br>A  ll I                  want is to sell the goods,     t                                     hen we'll be     on our way again. With this, we're even.<br><br>— Boris
# target       : Go to Palina   and call in the favo r she still owes us                                        .<br> Tell  her that you just want    to sell the goods  and that she'll be rid of us afterwards. Then we'll   call                    it              even.<br><br>— Boris
# Original translation: パリーナのところに行って、まだ返してもらってない恩を請求してこい。<br>ただ商品を売りたいだけだって言って、あとはお互いにスッキリするってことを伝えろ。これでおあいこだな。<br><br>— ボリス
# Updated translation : パリーナのところに行って、まだ返してもらってない恩を請求してこい。<br>ただ商品を売りたいだけだって言って、あとはお互いにスッキリするって伝えろ。これでおあいこだ。<br><br>— ボリス
#
# ------
# Dialog/NPC_Gerdwin_ja.loc
# Plh_235
# ground truth :  Let's both     pay them a visit...
# target       : I          will pay them a visit...
# Original translation: 彼らのところに行ってくるよ…
# Updated translation : 彼らのところに行ってくる…
#
# ------
# Dialog/NPC_Lukan_ja.loc
# Plh_15
# ground truth : Say, where were you last night? I didn't see you   in the  bunkhouse. Long night, huh? *smirks*
# target       : Say, where were you last night? I didn't see you la   t er          . Long night, huh? *smirks*
# Original translation: 昨晩はどこにいたの？後で君を見かけなかったよ。長い夜だったね、ふふ。 *ニヤリ*
# Updated translation : 昨晩はどこにいたの？後で君を見かけなかったよ。長い夜だったね、ふふ。 *ニヤリ*
#
# ------
# Dialog/NPC_Ruslan_ja.loc
# Plh_47
# ground truth : I've got to admit: With all the meat you've gotten for her, this is really del cious. *licks his lips*
# target       : I've got to admit: With all the meat you've gotten for her, this is really delicious. *licks his lips*
# Original translation: 認めるしかないな。お前が彼女のために集めた肉のおかげで、これは本当に美味い。*唇を舐める*
# Updated translation : 認めざるを得ないな。お前が彼女のために集めた肉のおかげで、これは本当に美味い。*唇を舐める*
#
# ------
# Dialog/NPC_Mombert_ja.loc
# Plh_744
# ground truth : We'll do our part, you do yours.
# target       : We'll do our part, you do yours. Find the next Divine Crystal in the Forest Primeval west of the Remnants' camp!
# Original translation: 俺たちは自分の役割を果たすから、お前はお前の役割を果たせ。次の神のクリスタルは、はぐれ者のキャンプの西にある原始の森にあるぞ！
# Updated translation : 俺たちは自分の役割を果たすから、お前はお前の役割を果たせ。次の神のクリスタルは、はぐれ者のキャンプの西にある原始の森にあるぞ！
#
# ------
# Dialog/NPC_Morvin_ja.loc
# Plh_109
# ground truth : I haven't forgotten that you helped me fix    tha      t b   attle          . And I promised you something...
# target       : I haven't forgotten that you helped me    get th e fight  up a    nd running. And I promised you something...
# Original translation: あの戦いを始めるのを手伝ってくれたことは忘れてない。で、君に約束したことがある…
# Updated translation : あの戦いを始めるのを手伝ってくれたことは忘れてない。で、君に約束したことがある…
#
# ------
# Dialog/NPC_Meluna_ja.loc
# Plh_118
# ground truth : Say ... k ann you tense other stuff as well?
# target       : Say ...  ca n you tense other stuff as well?
# Original translation: ねえ…他のものも緊張させることできる？
# Updated translation : ねえ…他のものも緊張させられる？
#
# ------
# Dialog/NPC_Bardok_ja.loc
# Plh_28
# ground truth : If you want to                                       le       a           rn                                 b                                                                        l acksmithing, you'll have to go to Chunnaic. It might be in vain, though — she would n't teach    even m    e  .
# target       : If you want to make weapons and armor, you're out of l uck. That takes year s of practice. You would have to be apprenticed to Chunnaic. She is the master smith of Nemeton, but she alr                       e               a                                          dy        has a      student.
# Original translation: 武器や防具を作りたいなら、運が悪いな。何年も練習が必要だし、チュナイクに弟子入りしなきゃならない。彼女はネメトンの名工だけど、もう一人弟子がいるんだ。
# Updated translation : 武器や防具を作りたいなら、運が悪いな。何年も練習が必要だし、チュナイクに弟子入りしなきゃならない。彼女はネメトンの名工だけど、もう一人弟子がいるんだ。
# Plh_48
# ground truth : If  y  ou   c an get him to leave me in peace, the        n we    can share   my spot in the Deep Mine. I'm curious whether you'll manage it.
# target       : I t  should cu     t                           th rough bon  e lik        e bu      t    t                               er                 .
# Original translation: 骨をバターみたいにスパッと切れるはずだ。
# Updated translation : 骨をバターみたいにスパッと切れるはずだ。
#
# ------
# Dialog/NPC_Mottek_ja.loc
# Plh_188
# ground truth : Once you're down in the Pit, watch the way you wield your     axe. You don't want to destroy the precious silver. Strike carefully and maintain a steady pace.
# target       : Once you're down in the Pit, watch the way you wield your pickaxe. You don't want to destroy the precious silver. Strike carefully and maintain a steady pace.
# Original translation: 一度ピットに降りたら、つるはしの振り方に気をつけろ。貴重な銀を壊しちまうことになるからな。慎重に打って、一定のペースを保て。
# Updated translation : 一度ピットに降りたら、つるはしの振り方に気をつけろ。貴重な銀を壊しちまうことになるからな。慎重に叩いて、一定のペースを保て。
#
# ------
# Dialog/NPC_Ruhan_ja.loc
# Plh_41
# ground truth : I hope I haven't been kiddingd myself. But everything's going to work out! Ruhan is now a Hewer!
# target       : I hope I haven't been kidding  myself. But everything's going to work out! Ruhan is now a Hewer!
# Original translation: 自分を騙してないといいけど、すべてうまくいくさ！ルハンは今や切り出し屋になったんだから！
# Updated translation : 自分を騙してないといいけど、すべてうまくいくはずだ！ルハンは今や切り出し屋になったんだから！
#
# ------
# Dialogue/RedTowerPedestral_ja.loc
# Plh_1
# ground truth : *You see a sculpture. Its design resembles that of         the feather                                . It'  s shaped like            a fox's paw.*
# target       : *You see a sculpture                       that   is, like the feather, covered in filigree engravings. It  is shaped like the paw of a fox      .*
# Original translation: 彫刻が目に入る。羽のように、細かい透かし彫りが施されている。狐の足の形をしている。
# Updated translation : 彫刻が目に入る。羽のように、細かい透かし彫りが施されている。狐の足の形をしている。
#
# ------
# CrimesReactions_ja.loc
# Plh_109
# ground truth : Head straight through, eastward, then up     . Let's give it everything we've got today — the end's in sight!
# target       : Head straight through, eastward, then   north. Let's give it everything we've got today — the end's in sight!
# Original translation: まっすぐ進んで、東へ行ったら北に向かおう。今日は全力を出そう — ゴールが見えてきたぞ！
# Updated translation : まっすぐ進んで、東へ行ったら北に向かおう。今日は全力を出そう — ゴールが見えてきたぞ！
#
# ------
# Items_ja.loc
# cons_flow_ferventCry_description
# ground truth : Increases your          damage resistance by [DamageResPercent] for [TimeAbs] seconds.
# target       : Increases your physical damage resistance by [DamageResPercent] for [TimeAbs] seconds.
# Original translation: [TimeAbs]秒間、物理ダメージ耐性を[DamageResPercent]増加させる。
# Updated translation : [TimeAbs]秒間、物理ダメージ耐性を[DamageResPercent]増加させるぜ。
# item_vipertooth_description
# ground truth : The slowing of poison is increases  by [SlowPercent].
# target       : The slowing of poison is increase d by [SlowPercent].
# Original translation: 毒の減速効果は[SlowPercent]によって増加する。
# Updated translation : 毒の減速効果は[SlowPercent]によって増加する。
# armor_chest_ruinenlager_gladiator_description
# ground truth : For each 1% lost health, you receive 1% less damage — up to a maximum of 90%<br><br>Armor, drenched in the blood of my enemies. Victory is mine.
# target       : For each  % lost health, you receive 1% less damage — up to a maximum of 90%<br><br>Armor, drenched in the blood of my enemies. Victory is mine.
# Original translation: 失った健康の%ごとに、受けるダメージが1%減る — 最大90%まで。<br><br>敵の血に染まった鎧。勝利は俺のものだ。
# Updated translation : 失った健康の%ごとに、受けるダメージが1%減る — 最大90%まで。<br><br>敵の血に染まった鎧。勝利は俺の手の中にある。
#
# ------
# Tutorial_ja.loc
# FirstConsFlow_Gamepad
# ground truth : You've found a spell scroll.<br>Pr  e                ss  $INPUTANIM:Op  e  nAbilities$ to open the menu and use      $INPUTANIM:PrevPanel$ to $INPUTANIM:NextPanel$ access the abilities tab. You can equip your spell scroll from there.<br>Spell scrolls can give you an edge in difficult fights; there's no point in hoarding them.
# target       : You've found a spell scroll.<br>  Open the menu and us e $INPUTANIM:  PrevP                             an    el$ to $INPUTANIM:                         NextPanel$ access the abilities tab. You can equip your spell scroll from there.<br>Spell scrolls can give you an edge in difficult fights; there's no point in hoarding them.
# Original translation: 呪文のスクロールを見つけたぞ。<br>メニューを開いて、$INPUTANIM:PrevPanel$ と $INPUTANIM:NextPanel$ を使ってアビリティタブにアクセスしよう。そこから呪文のスクロールを装備できる。<br>呪文のスクロールは厳しい戦闘で有利に働くから、ため込んでおく意味はないぜ。
# Updated translation : 呪文のスクロールを見つけたぞ。<br>メニューを開いて、$INPUTANIM:PrevPanel$ と $INPUTANIM:NextPanel$ を使ってアビリティタブにアクセスしよう。そこから呪文のスクロールを装備できる。<br>呪文のスクロールは厳しい戦闘で有利に働くから、ため込んでおく意味はないぜ。
#
# ------
# Buffs_ja.loc
# BleedingDescription
# ground truth :  Every second, you lose health          .
# target       : Y               ou lose health over time.
# Original translation: 時間が経つにつれて、体力が減っていく。
# Updated translation : 時間が経つにつれて、体力が減っていく。

# %%
print("--- Key Removed ---")

for file, diff_dict in differences.items():
    if diff_dict["key_removed"]:
        print(f"{file.replace("_en.", "_ja.")}")
        for key in diff_dict["key_removed"]:
            print(f"{key}")
            # TODO: remove from ja_dict and save
        print()

print('-- done ---')
# Out:
# --- Key Removed ---
# -- done ---
